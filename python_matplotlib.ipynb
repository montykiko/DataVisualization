# %% [markdown]
# matplotlib
# seaborn
# plotly

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ##  %matplotlib inline让图片显示在网页里，否则要用plot.show

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
z= [5,30,40,60]

# %%
plt.bar(range(len(z)),z)
# Out:
# <Container object of 4 artists>

# %%
plt.barh(range(len(z)),z,label='text')
plt.title('My Barchart')
plt.xlabel('count')
plt.ylabel('bins')
plt.text(30,2,'Third Bar')
plt.legend(loc=0)

# %%
data = np.random.randint(50,size=(3,5))

# %%
data
# Out:
# array([[44, 46, 17, 29, 26],
#        [ 6, 47,  5,  9, 26],
#        [27, 36,  0, 33,  7]])

# %%
X = np.arange(5)

# %%
X
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.bar(X + 0.00,data[0],color='b',width=0.25)
# Out:
# <Container object of 5 artists>

# %%
plt.bar(X + 0.25,data[1],color='g',width=0.25)
# Out:
# <Container object of 5 artists>

# %%
plt.bar(X + 0.5,data[2],color='y',width=0.25)
# Out:
# <Container object of 5 artists>

# %%
plt.bar(X + 0.00,data[0],color='b',width=0.25)
plt.bar(X + 0.25,data[1],color='g',width=0.25)
plt.bar(X + 0.5,data[2],color='y',width=0.25)
# Out:
# <Container object of 5 artists>

# %%
plt.bar(X,data[0],color='b')
plt.bar(X,data[1],color='g',bottom=data[0])
plt.bar(X,data[1],color='y',bottom=data[0]+data[1])
# Out:
# <Container object of 5 artists>

# %%
x = np.random.rand(1000,2)

# %%
x
# Out:
# array([[ 0.9576078 ,  0.31083108],
#        [ 0.19573634,  0.14285112],
#        [ 0.75120449,  0.91357566],
#        ...,
#        [ 0.64555194,  0.44210033],
#        [ 0.92690763,  0.84811472],
#        [ 0.82676047,  0.31293613]])

# %%
plt.scatter(x[:,0],x[:,1])

# %%
plt.hist(x[:,0],bins=20)
# Out:
# (array([ 51.,  37.,  51.,  54.,  55.,  63.,  41.,  40.,  53.,  50.,  53.,
#          44.,  49.,  41.,  54.,  44.,  54.,  64.,  56.,  46.]),
#  array([  6.15936582e-04,   5.05755219e-02,   1.00535107e-01,
#           1.50494693e-01,   2.00454278e-01,   2.50413863e-01,
#           3.00373448e-01,   3.50333034e-01,   4.00292619e-01,
#           4.50252204e-01,   5.00211790e-01,   5.50171375e-01,
#           6.00130960e-01,   6.50090546e-01,   7.00050131e-01,
#           7.50009716e-01,   7.99969302e-01,   8.49928887e-01,
#           8.99888472e-01,   9.49848058e-01,   9.99807643e-01]),
#  <a list of 20 Patch objects>)

# %%
x = np.random.rand(1000,6)

# %%
plt.boxplot(x)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1135dccf8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1136c37b8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1136c8a90>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1136c8240>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x1135dcef0>,
# ...
#   <matplotlib.lines.Line2D at 0x113737710>]}

# %%
import seaborn as seb

# %%
plt.boxplot(x)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x113896f60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1138a8a20>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1138b0cf8>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1138b04a8>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x1138a1940>,
# ...
#   <matplotlib.lines.Line2D at 0x11391f978>]}

# %% [markdown]
# ##  颜色代码见ppt

# %%
T = np.linspace(-np.pi,np.pi,1024)

# %%
len(T)
# Out:
# 1024

# %%
grid_size = (4,2)

# %%
plt.subplot2grid(grid_size,(0,0),rowspan = 3,colspan = 1)
plt.plot(np.sin(2*T),np.cos(0.5*T),c ='k')

plt.subplot2grid(grid_size,(0,1),rowspan = 3,colspan = 1)
plt.plot(np.cos(3*T),np.sin(T),c = 'r')

plt.subplot2grid(grid_size,(3,0),rowspan = 1,colspan = 2)
plt.plot(np.sin(1.5*T),np.cos(2*T),c = 'y')

plt.tight_layout()

# %%
f,arr = plt.subplots(2,2)
arr[0,0].plot(data[0],data[1])
arr[0,0].set_title('figure1')

arr[1,1].scatter(data[0],data[2])

# %%
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax1.scatter(data[0],data[1],c = 'r')

ax2 = fig.add_subplot(223)
ax2.plot(data[0],data[2],c = 'y')

# %%
seb.axes_style()
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': 'white',
#  'axes.facecolor': '#EAEAF2',
#  'axes.grid': True,
#  'axes.labelcolor': '.15',
#  'axes.linewidth': 0.0,
#  'figure.facecolor': (1, 1, 1, 0),
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'image.cmap': 'Greys',
#  'legend.frameon': False,
#  'legend.numpoints': 1,
#  'legend.scatterpoints': 1,
#  'lines.solid_capstyle': 'round',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'xtick.direction': 'out',
#  'xtick.major.size': 0.0,
#  'xtick.minor.size': 0.0,
#  'ytick.color': '.15',
#  'ytick.direction': 'out',
#  'ytick.major.size': 0.0,
#  'ytick.minor.size': 0.0}

# %%
# ?seb.set_style

# %%
seb.set_style('whitegrid')
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax1.scatter(data[0],data[1],c = 'r')

ax2 = fig.add_subplot(223)
ax2.plot(data[0],data[2],c = 'y')

# %%
# ?seb.set_context()

# %%
seb.set_style('whitegrid')
seb.set_context('poster')
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax1.scatter(data[0],data[1],c = 'r')

ax2 = fig.add_subplot(223)
ax2.plot(data[0],data[2],c = 'y')

# %%
seb.set_palette?

# %%
seb.set_style('whitegrid')
seb.set_palette('hls')
seb.set_context('poster')
fig = plt.figure()
ax1 = fig.add_subplot(221)
ax1.scatter(data[0],data[1],c = 'r')

ax2 = fig.add_subplot(223)
ax2.plot(data[0],data[2],c = 'y')
